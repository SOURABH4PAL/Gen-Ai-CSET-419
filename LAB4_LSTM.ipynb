# %%
text = """
artificial intelligence is transforming modern society.
it is used in healthcare finance education and transportation.
machine learning allows systems to improve automatically with experience.
data plays a critical role in training intelligent systems.
large datasets help models learn complex patterns.
deep learning uses multi layer neural networks.
neural networks are inspired by biological neurons.
each neuron processes input and produces an output.
training a neural network requires optimization techniques.
gradient descent minimizes the loss function.
"""

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.utils import to_categorical

# %%
text = text.lower()

chars = sorted(list(set(text)))
char_to_idx = {c: i for i, c in enumerate(chars)}
idx_to_char = {i: c for i, c in enumerate(chars)}

vocab_size = len(chars)
print("Vocabulary size:", vocab_size)
# Out:
# Vocabulary size: 28

# %%
seq_length = 40
X = []
y = []

for i in range(len(text) - seq_length):
    X.append([char_to_idx[c] for c in text[i:i+seq_length]])
    y.append(char_to_idx[text[i+seq_length]])

X = np.array(X)
y = to_categorical(y, num_classes=vocab_size)

X = X / float(vocab_size)
X = X.reshape(X.shape[0], X.shape[1], 1)

# %%
model = Sequential()
model.add(LSTM(128, input_shape=(seq_length, 1)))
model.add(Dense(vocab_size, activation='softmax'))

model.compile(
    loss='categorical_crossentropy',
    optimizer='adam'
)

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 128)            │        66,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 28)             │         3,612 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 70,172 (274.11 KB)
#  Trainable params: 70,172 (274.11 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X, y, epochs=50, batch_size=64)
# Out:
# Epoch 1/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 2.9057
# Epoch 2/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 2.9353
# Epoch 3/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 2.9087
# Epoch 4/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 2.9483
# Epoch 5/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 2.9525
# Epoch 6/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 2.9739
# Epoch 7/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 2.9492
# Epoch 8/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 2.9520
# Epoch 9/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 2.9145
# Epoch 10/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 2.9162
# Epoch 11/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - loss: 2.9055
# Epoch 12/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - loss: 2.9146
# Epoch 13/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 2.9197
# Epoch 14/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 2.9265
# Epoch 15/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 2.9225
# Epoch 16/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 2.9501
# Epoch 17/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 2.9342
# Epoch 18/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 2.9408
# Epoch 19/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 2.8944
# Epoch 20/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 2.9365
# Epoch 21/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 2.9749
# Epoch 22/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 2.9213
# Epoch 23/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 2.9009
# Epoch 24/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 2.9237
# Epoch 25/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 2.9275
# Epoch 26/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 2.8873
# Epoch 27/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 2.9140
# Epoch 28/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 2.9352
# Epoch 29/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 2.8936
# Epoch 30/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 2.8815
# Epoch 31/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 2.9197
# Epoch 32/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 2.8775
# Epoch 33/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - loss: 2.8904
# Epoch 34/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - loss: 2.8892
# Epoch 35/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - loss: 2.9110
# Epoch 36/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 2.9194
# Epoch 37/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 2.8994
# Epoch 38/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 2.9365
# Epoch 39/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 2.9249
# Epoch 40/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 2.9092
# Epoch 41/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 2.9403
# Epoch 42/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 2.8904
# Epoch 43/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 2.8683
# Epoch 44/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 2.8723
# Epoch 45/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 2.8471
# Epoch 46/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 2.8976
# Epoch 47/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 2.8392
# Epoch 48/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 2.8839
# Epoch 49/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 2.8510
# Epoch 50/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 2.8384

# %%
def generate_text(seed_text, length=200):
    result = seed_text

    for _ in range(length):
        padded = result[-seq_length:].rjust(seq_length)
        seq = [char_to_idx[c] for c in padded]

        seq = np.array(seq) / float(vocab_size)
        seq = seq.reshape(1, seq_length, 1)

        prediction = model.predict(seq, verbose=0)
        next_index = np.argmax(prediction)
        next_char = idx_to_char[next_index]

        result += next_char

    return result

# %%
seed = "artificial intelligence is "
print(generate_text(seed))
# Out:
# artificial intelligence is nnn nenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenenene
